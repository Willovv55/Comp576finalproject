# %%
# 1. Mount Google Drive (if your data is on Drive)
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# 2. Import necessary libraries
import os
import re
import shutil

# Define source directory containing your images
source_dir = '/content/drive/MyDrive/UTKFace/55_75'  # Change this path to your images folder

# Define the base directory where classified images will be stored
dest_base_dir = '/content/drive/MyDrive/UTKFace/classified_images_55_75'  # Change as needed

# Define mappings for gender and race based on expected values in file names
gender_map = {'0': "Male", '1': "Female"}
race_map = {'0': "White", '1': "Black", '2': "Asian", '3': "Indian", '4': "Others"}

# Create the base destination folder if it doesn't exist
if not os.path.exists(dest_base_dir):
    os.makedirs(dest_base_dir)

# Regex pattern to extract age, gender, and race from filenames.
# This pattern matches filenames in the format: <age>_<gender>_<race>_<other_info>.jpg
pattern = r"(\d+)_([01])_([0-4])_.*\.jpg(?:\.chip\.jpg)?$"

# 3. Process each file: extract classification info and copy file to respective folder.
for file_name in os.listdir(source_dir):
    # Only process .jpg files (modify if needed for other file types)
    if file_name.lower().endswith(".jpg"):
        match = re.match(pattern, file_name)
        if match:
            age, gender_val, race_val = match.groups()
            # Map the extracted string labels to descriptive text using our maps
            gender_class = gender_map[gender_val]
            race_class = race_map[race_val]

            # Create a destination folder for this classification:
            # e.g., /.../classified_images/Male/White/
            dest_folder = os.path.join(dest_base_dir, gender_class, race_class)
            if not os.path.exists(dest_folder):
                os.makedirs(dest_folder)

            # Define source and destination file paths
            src_file = os.path.join(source_dir, file_name)
            dest_file = os.path.join(dest_folder, file_name)

            # Copy the file from source to destination folder
            shutil.copy(src_file, dest_file)

            print(f"Copied {file_name} to {dest_folder}")
# Out:
# Copied 65_0_2_20170120223049075.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Asian
# Copied 65_0_3_20161220221926818.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Indian
# Copied 65_0_0_20170120222749697.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 65_0_1_20170113174447314.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Black
# Copied 65_0_0_20170120223704629.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 65_0_0_20170120221357579.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 65_0_1_20170120222944643.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Black
# Copied 65_0_1_20170117165348576.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Black
# Copied 65_0_1_20170120223219484.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Black
# Copied 65_0_0_20170117185953586.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 65_0_2_20161219193311243.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Asian
# Copied 65_0_0_20170120224023991.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 65_0_2_20170111205651706.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Asian
# Copied 65_0_3_20170119201141428.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Indian
# Copied 65_0_1_20170111171747640.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Black
# Copied 65_0_3_20170119210250623.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Indian
# Copied 65_0_2_20170112205504482.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Asian
# Copied 65_0_1_20170117171258523.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Black
# Copied 65_0_2_20170112223941923.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Asian
# Copied 65_0_0_20170117191819572.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 65_0_1_20170117182422917.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Black
# Copied 65_0_1_20170120223029947.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Black
# Copied 65_0_1_20170117193640771.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Black
# Copied 65_0_0_20170117172111769.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 65_0_3_20170117171142579.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Indian
# Copied 65_0_0_20170120225159632.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 65_0_0_20170120223720869.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 65_0_1_20170111181750510.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Black
# Copied 65_0_3_20170119203933382.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Indian
# Copied 65_0_1_20170117192046226.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Black
# Copied 65_0_3_20170112222321514.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Indian
# Copied 65_0_3_20170105180657742.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Indian
# Copied 65_0_0_20170117204225231.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 65_0_1_20170120134639935.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Black
# Copied 65_0_1_20170120222929626.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Black
# Copied 65_0_0_20170117171106484.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 65_0_3_20170119171819688.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Indian
# Copied 65_0_0_20170120223009912.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 65_0_0_20170120223054947.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 65_0_1_20170113174052843.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Black
# Copied 65_0_3_20170109143021566.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Indian
# Copied 65_0_3_20170119205841400.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Indian
# Copied 65_0_1_20170117193649266.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Black
# Copied 65_0_3_20170119205855505.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Indian
# Copied 65_0_0_20170120222348112.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 65_0_0_20170117172707792.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 65_0_3_20170119164246893.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Indian
# Copied 65_0_0_20170120225216335.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 65_0_1_20170113184825438.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Black
# Copied 65_0_0_20170117171434763.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 65_0_0_20170120222816177.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 65_0_0_20170120221835349.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 65_1_0_20170110140804905.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 65_1_0_20170120225024135.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 66_0_0_20170111222127534.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 65_1_0_20170110160643954.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 65_1_0_20170103184138483.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 65_1_0_20170110125326249.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 65_1_1_20170113012637127.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/Black
# Copied 65_1_0_20170110131714147.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 65_1_0_20170110141251497.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 65_1_0_20170110135759710.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 65_1_2_20161219160537365.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/Asian
# Copied 65_1_1_20170117010316709.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/Black
# Copied 65_1_3_20170109143047483.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/Indian
# Copied 65_1_0_20170110160643907.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 65_1_0_20170110122721426.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 66_0_0_20170104184857950.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 65_1_1_20170120222613985.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/Black
# Copied 65_1_0_20170110181102968.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 65_1_1_20170113002051572.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/Black
# Copied 65_1_0_20170110182826116.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 65_1_0_20170110152931044.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 65_1_0_20170110141348912.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 65_1_0_20170117173004744.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 65_1_0_20170120224801168.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 65_1_0_20170117190355010.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 65_1_0_20170110131312112.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 66_0_0_20170111203309589.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 65_1_3_20170109135755974.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/Indian
# Copied 65_1_0_20170110123252108.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 66_0_0_20170104213607429.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 65_1_1_20170117193956961.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/Black
# Copied 65_1_0_20170117092234692.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 65_1_1_20170117163545690.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/Black
# Copied 65_1_0_20170110143236073.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 65_1_0_20170120223955918.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 66_0_0_20170117191832603.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 65_1_0_20170110150303627.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 65_1_3_20170109141910621.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/Indian
# Copied 65_1_0_20170110152814579.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 65_1_1_20170113012531920.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/Black
# Copied 65_1_0_20170110143540983.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 65_1_0_20170110122605770.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 66_0_0_20170120225919754.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 65_1_0_20170120222039350.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 66_0_0_20170109015504776.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 65_1_0_20170120133545325.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 66_0_0_20170120225917395.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 66_0_0_20170109013237361.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 65_1_0_20170110143547028.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 65_0_3_20170120225250881.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Indian
# Copied 65_1_0_20170116220142214.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 65_1_0_20170110175818279.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 65_1_3_20170117135236191.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/Indian
# Copied 65_1_0_20170110141141881.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 66_0_0_20170105173731829.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 65_1_0_20170110122725239.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 65_1_0_20170110160643923.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 65_1_0_20170110140444495.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 65_1_0_20170110183018880.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 65_1_0_20170120225123328.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 65_1_0_20170110131531222.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 65_1_0_20170110141104816.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 65_1_1_20170112215403296.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/Black
# Copied 65_1_0_20170110154347701.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 66_0_0_20170117175358556.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 65_1_0_20170110140917161.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 65_1_0_20170110143514848.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 65_1_1_20170113012956231.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/Black
# Copied 66_0_0_20170116233250943.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 65_1_0_20170110154550300.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 65_1_0_20170110140924521.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 65_1_0_20170117171643563.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 65_1_4_20170117185548913.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/Others
# Copied 65_1_1_20170110124227365.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/Black
# Copied 65_1_0_20170110123555351.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 65_1_4_20170117203945447.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/Others
# Copied 65_1_0_20170117172124978.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 65_1_0_20170110131349129.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 65_1_0_20170110151430189.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 65_1_0_20170110141013017.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 65_1_0_20170110181703594.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 65_1_0_20170110182002744.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 65_1_0_20170110132559859.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 65_0_4_20170109005604594.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Others
# Copied 65_1_3_20170119201536077.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/Indian
# Copied 65_1_1_20170112220241647.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/Black
# Copied 65_1_2_20170105174503015.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/Asian
# Copied 65_1_2_20170112224125018.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/Asian
# Copied 65_1_0_20170117173915503.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 66_0_0_20170116233247357.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 65_1_0_20170110160643938.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 65_1_0_20170110132512700.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 65_1_0_20170110151351064.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 66_0_0_20170120221744629.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 65_1_0_20170110132446063.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 65_1_0_20170110122548648.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 66_0_0_20170117000141332.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 65_1_0_20170103175408672.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 66_0_0_20170104184119566.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 65_1_3_20170119202621117.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/Indian
# Copied 65_1_0_20170110140958665.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 65_1_1_20170117184041200.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/Black
# Copied 66_0_0_20170111210358051.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 66_0_0_20170104002319293.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 65_1_0_20170110175333844.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 65_1_0_20170110133937781.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 65_1_0_20170110180059564.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 65_1_0_20170110125535454.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 67_0_0_20170117195143525.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 67_0_0_20170120230048298.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 66_1_0_20170110132405672.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 67_0_0_20170109002521701.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 67_0_0_20170111193821219.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 66_1_0_20170110123225778.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 66_1_0_20170110160644001.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 66_0_1_20170113185346153.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Black
# Copied 67_0_0_20170105172950852.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 67_0_0_20170108235729190.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 66_0_3_20170119160336443.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Indian
# Copied 67_0_0_20170109150725032.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 67_0_0_20170120225722729.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 67_0_0_20170120224558687.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 67_0_0_20170109012902657.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 66_0_3_20170119180756808.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Indian
# Copied 66_0_4_20170104185439302.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Others
# Copied 66_1_0_20170110140711170.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 67_0_0_20170117204838537.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 66_1_0_20170110140921650.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 66_1_0_20170110132135290.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 66_1_0_20170110123144558.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 67_0_0_20170120225206184.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 66_0_3_20170119153511665.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Indian
# Copied 66_1_0_20170110140422693.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 66_1_0_20170105174521629.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 66_1_0_20170110143321085.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 67_0_0_20170104213103526.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 66_1_0_20170110122200303.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 66_1_0_20170110160643970.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 67_0_0_20170104200734185.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 66_0_3_20170119212007271.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Indian
# Copied 66_1_0_20170110140413980.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 66_1_0_20170110141312880.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 67_0_0_20170120225145905.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 67_0_0_20170117192237235.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 66_1_0_20170110131902685.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 66_1_0_20170110153031033.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 67_0_0_20170120230050170.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 67_0_0_20170113210319928.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 67_0_0_20170111222156279.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 66_0_2_20170111205753656.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Asian
# Copied 66_1_0_20170110175837753.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 67_0_0_20170104184245598.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 66_1_0_20170117175408412.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 66_0_3_20170117195129091.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Indian
# Copied 66_1_0_20170110160644016.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 66_0_1_20170117195116702.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Black
# Copied 66_1_1_20170110153026621.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/Black
# Copied 67_0_0_20170104213337429.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 66_1_0_20170110141136857.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 67_0_0_20170109002158153.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 67_0_0_20170112205632732.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 67_0_0_20170109002906472.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 67_0_0_20170120224822464.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 67_0_0_20170104213345869.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 67_0_0_20170113185521375.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 66_0_3_20170119180856366.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Indian
# Copied 66_1_0_20170110132126931.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 66_1_0_20170110160643985.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 66_1_0_20170110141754767.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 67_0_1_20170113161329852.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Black
# Copied 66_1_0_20170110140426872.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 66_1_0_20170110140456209.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 66_1_0_20170110140430277.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 67_0_0_20170104023306558.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 66_1_0_20170110140814578.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 67_0_0_20170104171355258.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 66_0_3_20170119212006015.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Indian
# Copied 67_0_0_20170117163339177.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 66_1_0_20170110122210413.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 66_1_0_20170105173707677.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 67_0_0_20170120225129440.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 66_1_0_20170110141120112.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 66_1_0_20170110124457390.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 66_0_1_20170111195703017.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Black
# Copied 67_0_0_20170120224536320.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 66_0_1_20170111171747645.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Black
# Copied 66_1_0_20170117091537933.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 67_0_0_20170104185427710.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 66_0_3_20170113185512785.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Indian
# Copied 66_1_0_20170110132508785.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 66_1_0_20170110141430168.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 67_0_0_20170113185523838.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 67_0_0_20170120225706103.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 66_1_4_20170117091830720.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/Others
# Copied 67_0_0_20170120223724366.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 66_0_0_20170120225927930.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 67_0_0_20170104185241950.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 67_0_0_20170120223037554.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 66_1_0_20170110140359075.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 67_0_0_20170104212901716.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 67_0_0_20170120224529039.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 66_0_3_20170104213153549.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Indian
# Copied 66_1_0_20170110131727840.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 66_1_0_20170110132123247.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 67_0_0_20170103184144627.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 66_1_0_20170110140952713.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 67_0_0_20170111171747651.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 66_1_0_20170110122914995.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 66_1_0_20170110131639960.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 66_1_1_20170113000154762.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/Black
# Copied 68_0_2_20170111205006920.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Asian
# Copied 68_0_0_20170111171747655.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 68_0_0_20170117172643040.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 68_0_0_20170117172835921.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 68_0_0_20170104213159413.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 68_0_0_20170117155857481.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 68_0_0_20170117184556032.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 68_0_0_20170111200803612.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 68_0_0_20170111205855178.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 68_0_1_20170113152833080.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Black
# Copied 67_1_0_20170110154623389.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 67_0_1_20170117172054412.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Black
# Copied 67_1_0_20170110131843433.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 68_0_0_20170117172902192.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 68_0_0_20170120224541303.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 67_0_3_20170116193543456.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Indian
# Copied 68_0_0_20170105173736735.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 68_0_0_20170111202304919.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 67_0_1_20170117143308243.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Black
# Copied 68_0_0_20170111221712885.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 68_0_0_20170119212026025.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 67_1_0_20170120223746014.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 67_0_3_20170119212008184.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Indian
# Copied 67_0_1_20170117143355801.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Black
# Copied 68_0_0_20170111205947306.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 68_0_1_20170111203305459.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Black
# Copied 67_0_1_20170120223307141.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Black
# Copied 68_0_0_20170117171825450.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 68_0_0_20170109012554003.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 67_0_3_20170119212010042.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Indian
# Copied 67_1_0_20170109142541820.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 67_0_2_20170112224619492.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Asian
# Copied 67_1_3_20170109132529672.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/Indian
# Copied 68_0_1_20170113152656361.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Black
# Copied 68_0_0_20170109015134679.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 68_0_0_20170109002614945.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 67_1_0_20170109150548754.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 67_1_0_20170110143255682.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 68_0_1_20170111194909799.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Black
# Copied 68_0_1_20170117170414776.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Black
# Copied 68_0_0_20170117172618723.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 67_1_0_20170110153312575.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 67_0_3_20170105181005916.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Indian
# Copied 68_0_0_20170111200435940.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 68_0_0_20170111205253736.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 67_0_1_20170120224828928.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Black
# Copied 68_0_0_20170104213632941.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 68_0_0_20170111204834965.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 67_1_0_20170120224807800.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 67_0_3_20170119212012082.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Indian
# Copied 68_0_0_20170117172721512.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 67_1_0_20170105173734477.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 67_0_2_20170116193956693.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Asian
# Copied 68_0_0_20170111222231920.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 68_0_1_20170111204337366.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Black
# Copied 68_0_1_20170117172339634.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Black
# Copied 68_0_1_20170113181302934.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Black
# Copied 67_1_0_20170110140843433.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 68_0_0_20170117171408597.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 67_0_1_20170117185950062.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Black
# Copied 68_0_0_20170111171747660.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 68_0_0_20170111205927835.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 67_0_3_20170119212020850.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Indian
# Copied 68_0_0_20170113185525480.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 68_0_0_20170104213011828.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 67_1_0_20170104170235233.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 67_1_0_20170110152923990.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 68_0_0_20170104213635701.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 67_0_2_20170112224629884.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Asian
# Copied 68_0_1_20170117192237032.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Black
# Copied 67_1_0_20170110152820302.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 67_1_2_20161219194437956.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/Asian
# Copied 68_0_0_20170117174131505.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 67_0_3_20170117134845691.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Indian
# Copied 68_0_1_20170117193455181.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Black
# Copied 67_1_0_20170110140730634.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 67_0_1_20170117172510754.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Black
# Copied 67_1_0_20170104213602661.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 67_1_1_20170110125353438.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/Black
# Copied 67_0_3_20161220221736930.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Indian
# Copied 67_1_0_20170110140434646.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 68_0_0_20170104184637742.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 68_0_0_20170117172924008.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 68_0_0_20170117171135900.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 68_0_1_20170111195820243.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Black
# Copied 68_0_1_20170117194555228.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Black
# Copied 68_0_0_20170111202050714.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 67_0_1_20170113175755885.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Black
# Copied 67_1_0_20170110143329621.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 67_0_3_20170119212009145.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Indian
# Copied 67_1_3_20170109150650035.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/Indian
# Copied 67_1_0_20170110140452381.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 67_0_3_20170105175613302.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Indian
# Copied 67_1_0_20170120224818072.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 68_0_0_20170111204848471.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 67_1_0_20170120225003182.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 67_1_3_20170109151006621.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/Indian
# Copied 68_0_0_20170111221718605.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 68_0_0_20170105174949806.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 68_0_1_20170111224026548.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Black
# Copied 67_1_0_20170110180054361.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 68_0_0_20170111203927639.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 68_0_0_20170104185731268.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 68_0_0_20170117172347609.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 67_0_1_20170117190207133.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Black
# Copied 67_0_3_20170119212019810.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Indian
# Copied 68_0_0_20170111200645876.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 68_0_0_20170104184826326.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 67_1_0_20170110120952264.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 67_1_1_20170113185517320.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/Black
# Copied 68_0_0_20170117172938504.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 68_1_0_20170103184201412.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 68_0_2_20170116193554465.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Asian
# Copied 69_1_0_20170110131527801.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 69_0_0_20170111200511915.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 69_1_0_20170110141848983.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 68_1_0_20170110160644032.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 69_0_0_20170104185333726.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 69_1_0_20170110151454373.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 69_1_0_20170110141308465.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 69_0_0_20170104184837071.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 69_1_0_20170110152927513.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 69_1_0_20170110141630303.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 68_0_2_20170116193548368.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Asian
# Copied 69_1_0_20170110141304032.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 68_0_3_20170113185529025.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Indian
# Copied 69_0_1_20170116205546933.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Black
# Copied 68_1_0_20170110175345439.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 68_0_2_20170112224243075.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Asian
# Copied 69_1_0_20170110175853077.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 68_1_0_20170110131335562.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 69_1_0_20170110140355514.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 69_1_1_20170117195205819.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/Black
# Copied 69_0_0_20170109011208585.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 69_0_3_20170112224615052.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Indian
# Copied 69_1_0_20170109150615726.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 69_1_0_20170110122730511.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 68_1_0_20170109221126838.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 68_1_0_20170110143406927.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 68_1_0_20170110141150729.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 68_1_0_20170110143337087.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 69_0_0_20170116193756964.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 68_1_1_20170116161411128.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/Black
# Copied 69_1_0_20170110152957666.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 68_1_0_20170110132430273.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 69_0_0_20170111203934092.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 68_0_2_20170116193700812.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Asian
# Copied 69_0_1_20170111203711198.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Black
# Copied 68_0_2_20170116193600328.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Asian
# Copied 68_1_1_20170110183842657.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/Black
# Copied 68_1_0_20170110122621083.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 69_1_0_20170110141527783.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 68_1_0_20170110140321752.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 69_1_0_20170110141854535.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/White
# Copied 69_0_1_20170113184924520.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Black
# ...
# Copied 58_0_0_20170104185326934.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 58_0_0_20170111204513437.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 58_0_0_20170111202848963.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 58_0_0_20170111201403999.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 58_0_0_20170113190658809.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 58_0_0_20170111205913082.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 58_0_0_20170117173108249.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 58_0_0_20170117172932280.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 58_0_0_20170105173636909.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 58_0_0_20170117135834808.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 58_0_0_20170105173531229.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 57_1_3_20170104234912850.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/Indian
# Copied 58_0_0_20170111195225616.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 58_0_0_20170104185347134.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 58_0_0_20170109012156576.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 58_0_0_20170104212603957.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 58_0_0_20170109012537557.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 58_0_0_20170117173317568.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 58_0_0_20170117191807907.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 58_0_0_20170109013800693.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 58_0_0_20170111195305743.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 58_0_0_20170117191839091.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 58_0_0_20170117191924885.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 58_0_0_20170117193250787.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 58_0_0_20170111200444658.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 58_0_0_20170117191805986.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 58_0_0_20170111171747501.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 58_0_0_20170113142246036.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 58_0_0_20170104184709517.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 58_0_0_20170109012759314.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 58_0_0_20170105173528685.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 58_0_0_20170104211841244.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 57_1_3_20170105001132532.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/Indian
# Copied 58_0_0_20170117191927955.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 58_0_0_20170117143055861.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 58_0_0_20170113210319275.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 58_0_0_20170117153829116.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 58_0_0_20170109015153214.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 58_0_0_20170117191918155.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 58_0_0_20170105173559373.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 58_0_0_20170104212025853.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 58_0_0_20170104002241806.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 57_1_3_20170109132601018.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Female/Indian
# Copied 58_0_1_20170113174947234.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Black
# Copied 58_0_3_20170104220928390.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Indian
# Copied 58_0_3_20170119165822974.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Indian
# Copied 58_0_0_20170117193913647.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 58_0_3_20170119211547537.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Indian
# Copied 58_0_1_20170113184850673.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Black
# Copied 58_0_0_20170120134510215.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 58_0_2_20170116193604774.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Asian
# Copied 58_0_2_20170116193610463.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Asian
# Copied 58_0_1_20170117193003224.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Black
# Copied 58_0_0_20170119211727401.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 58_0_1_20170109015140121.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Black
# Copied 58_0_0_20170120224606727.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 58_0_1_20170117193132038.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Black
# Copied 58_0_3_20170119211545409.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Indian
# Copied 58_0_1_20170113185358000.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Black
# Copied 58_0_3_20170119211558385.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Indian
# Copied 58_0_3_20170109142236643.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Indian
# Copied 58_0_2_20170117153650893.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Asian
# Copied 58_0_2_20170116193724888.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Asian
# Copied 58_0_1_20170111200022771.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Black
# Copied 58_0_3_20170119211523632.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Indian
# Copied 58_0_2_20170104213251605.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Asian
# Copied 58_0_3_20170119211538977.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Indian
# Copied 58_0_2_20170112205242580.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Asian
# Copied 58_0_1_20170117192230322.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Black
# Copied 58_0_0_20170120224551943.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 58_0_3_20170119195320690.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Indian
# Copied 58_0_0_20170120224926808.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 58_0_3_20170104220900702.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Indian
# Copied 58_0_1_20170113190411755.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Black
# Copied 58_0_1_20170104185127270.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Black
# Copied 58_0_1_20170117191843355.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Black
# Copied 58_0_1_20170113193258196.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Black
# Copied 58_0_1_20170117182453919.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Black
# Copied 58_0_0_20170120225226444.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 58_0_1_20170113190654777.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Black
# Copied 58_0_0_20170117204710599.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 58_0_1_20170117192005261.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Black
# Copied 58_0_1_20170117173247104.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Black
# Copied 58_0_1_20170117195329446.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Black
# Copied 58_0_0_20170120224627678.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 58_0_3_20170119211544361.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Indian
# Copied 58_0_0_20170117193906036.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 58_0_3_20170112205528628.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Indian
# Copied 58_0_1_20170117193000518.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Black
# Copied 58_0_3_20170119211539872.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Indian
# Copied 58_0_0_20170120224603295.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 58_0_3_20170109140942312.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Indian
# Copied 58_0_1_20170117193630275.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Black
# Copied 58_0_1_20170113185038112.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Black
# Copied 58_0_1_20170120222527209.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Black
# Copied 58_0_1_20170117193628506.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Black
# Copied 58_0_0_20170120224018686.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 58_0_0_20170120224706941.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 58_0_2_20170116193712612.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Asian
# Copied 58_0_1_20170113184906215.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Black
# Copied 58_0_3_20170112205533156.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Indian
# Copied 58_0_0_20170120224656976.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 58_0_0_20170120224611152.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 58_0_3_20170119211542128.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Indian
# Copied 58_0_3_20170119211548329.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Indian
# Copied 58_0_3_20170119211546505.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Indian
# Copied 58_0_1_20170111210843429.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Black
# Copied 58_0_2_20170116193608936.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Asian
# Copied 58_0_0_20170120222805833.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 58_0_1_20170113182450903.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Black
# Copied 58_0_0_20170120224549744.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 58_0_3_20170119211543234.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Indian
# Copied 58_0_3_20170113184919520.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Indian
# Copied 58_0_0_20170120224709007.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 58_0_0_20170117193919120.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 58_0_3_20170119192023433.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Indian
# Copied 58_0_1_20170117193633529.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Black
# Copied 58_0_2_20170116193704928.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Asian
# Copied 58_0_2_20170104212958196.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Asian
# Copied 58_0_0_20170117193911971.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 58_0_0_20170120224625496.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 58_0_0_20170120224608368.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 58_0_2_20170112222056864.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Asian
# Copied 58_0_0_20170117195023639.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 58_0_0_20170120224629472.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 58_0_0_20170120224650587.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 58_0_0_20170120224554712.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 58_0_2_20170104185526166.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Asian
# Copied 58_0_1_20170113175352418.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Black
# Copied 58_0_1_20170117204657521.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Black
# Copied 58_0_0_20170120224609760.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 58_0_0_20170117194037923.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 58_0_1_20170117160528648.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Black
# Copied 58_0_2_20170112205513042.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Asian
# Copied 58_0_3_20170119201636156.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Indian
# Copied 58_0_3_20170119181133308.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Indian
# Copied 58_0_1_20170111170138036.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Black
# Copied 58_0_0_20170120222516888.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White
# Copied 58_0_1_20170117184831471.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/Black
# Copied 58_0_0_20170120224028072.jpg.chip.jpg to /content/drive/MyDrive/UTKFace/classified_images_55_75/Male/White

# %%
# Mount Google Drive to access the dataset
from google.colab import drive
drive.mount('/content/drive')

import os
import random
import shutil

def split_dataset(source_dir: str, train_dir: str, test_dir: str, train_ratio: float = 0.8, seed: int = 42):
    """
    Splits images in each class subfolder of 'source_dir' into
    train and test sets according to 'train_ratio'.

    Parameters:
    - source_dir: str, path to the source dataset directory (e.g., containing the "Female" folder with class subfolders)
    - train_dir: str, path where the training set will be saved.
    - test_dir: str, path where the testing set will be saved.
    - train_ratio: float, ratio of images to place in the training set. (Default 0.8)
    - seed: int, random seed for shuffling.
    """

    # Set a fixed random seed for reproducibility
    random.seed(seed)

    # Create train and test directories if they do not exist
    os.makedirs(train_dir, exist_ok=True)
    os.makedirs(test_dir, exist_ok=True)

    # Iterate over each class folder in the source directory
    for class_name in os.listdir(source_dir):
        class_path = os.path.join(source_dir, class_name)

        # Process only directories (class folders)
        if os.path.isdir(class_path):
            # Get list of image files from the current class folder
            images = [
                f for f in os.listdir(class_path)
                if os.path.isfile(os.path.join(class_path, f)) and f.lower().endswith(('.jpg', '.jpeg', '.png'))
            ]

            # Shuffle the list to ensure randomness
            random.shuffle(images)

            # Determine the split index for train/test based on train_ratio
            split_idx = int(len(images) * train_ratio)
            train_images = images[:split_idx]
            test_images = images[split_idx:]

            # Create corresponding directories in train and test splits for the current class
            train_class_dir = os.path.join(train_dir, class_name)
            test_class_dir = os.path.join(test_dir, class_name)
            os.makedirs(train_class_dir, exist_ok=True)
            os.makedirs(test_class_dir, exist_ok=True)

            # Copy images to the training directory
            for img in train_images:
                src_path = os.path.join(class_path, img)
                dst_path = os.path.join(train_class_dir, img)
                shutil.copy2(src_path, dst_path)

            # Copy images to the testing directory
            for img in test_images:
                src_path = os.path.join(class_path, img)
                dst_path = os.path.join(test_class_dir, img)
                shutil.copy2(src_path, dst_path)

            print(f"Class '{class_name}': {len(train_images)} images in train, {len(test_images)} images in test.")

# Example usage:
if __name__ == "__main__":
    # Update these paths to match your Google Drive structure
    source_dir = '/content/drive/MyDrive/UTKFace/classified_images_55_75/Female'  # Replace with your dataset path
    train_dir = '/content/drive/MyDrive/UTKFace/55_75_train_female'     # Replace with your desired train output path
    test_dir  = '/content/drive/MyDrive/UTKFace/55_75_test_female'      # Replace with your desired test output path

    split_dataset(source_dir, train_dir, test_dir, train_ratio=0.8, seed=42)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Class 'White': 548 images in train, 137 images in test.
# Class 'Black': 90 images in train, 23 images in test.
# Class 'Asian': 26 images in train, 7 images in test.
# Class 'Indian': 65 images in train, 17 images in test.
# Class 'Others': 5 images in train, 2 images in test.

# %%
# Mount Google Drive to access the dataset
from google.colab import drive
drive.mount('/content/drive')

import os
import random
import shutil

def split_dataset(source_dir: str, train_dir: str, test_dir: str, train_ratio: float = 0.8, seed: int = 42):
    """
    Splits images in each class subfolder of 'source_dir' into
    train and test sets according to 'train_ratio'.

    Parameters:
    - source_dir: str, path to the source dataset directory (e.g., containing the "Female" folder with class subfolders)
    - train_dir: str, path where the training set will be saved.
    - test_dir: str, path where the testing set will be saved.
    - train_ratio: float, ratio of images to place in the training set. (Default 0.8)
    - seed: int, random seed for shuffling.
    """

    # Set a fixed random seed for reproducibility
    random.seed(seed)

    # Create train and test directories if they do not exist
    os.makedirs(train_dir, exist_ok=True)
    os.makedirs(test_dir, exist_ok=True)

    # Iterate over each class folder in the source directory
    for class_name in os.listdir(source_dir):
        class_path = os.path.join(source_dir, class_name)

        # Process only directories (class folders)
        if os.path.isdir(class_path):
            # Get list of image files from the current class folder
            images = [
                f for f in os.listdir(class_path)
                if os.path.isfile(os.path.join(class_path, f)) and f.lower().endswith(('.jpg', '.jpeg', '.png'))
            ]

            # Shuffle the list to ensure randomness
            random.shuffle(images)

            # Determine the split index for train/test based on train_ratio
            split_idx = int(len(images) * train_ratio)
            train_images = images[:split_idx]
            test_images = images[split_idx:]

            # Create corresponding directories in train and test splits for the current class
            train_class_dir = os.path.join(train_dir, class_name)
            test_class_dir = os.path.join(test_dir, class_name)
            os.makedirs(train_class_dir, exist_ok=True)
            os.makedirs(test_class_dir, exist_ok=True)

            # Copy images to the training directory
            for img in train_images:
                src_path = os.path.join(class_path, img)
                dst_path = os.path.join(train_class_dir, img)
                shutil.copy2(src_path, dst_path)

            # Copy images to the testing directory
            for img in test_images:
                src_path = os.path.join(class_path, img)
                dst_path = os.path.join(test_class_dir, img)
                shutil.copy2(src_path, dst_path)

            print(f"Class '{class_name}': {len(train_images)} images in train, {len(test_images)} images in test.")

# Example usage:
if __name__ == "__main__":
    # Update these paths to match your Google Drive structure
    source_dir = '/content/drive/MyDrive/UTKFace/classified_images_55_75/Male'  # Replace with your dataset path
    train_dir = '/content/drive/MyDrive/UTKFace/55_75_train_male'     # Replace with your desired train output path
    test_dir  = '/content/drive/MyDrive/UTKFace/55_75_test_male'      # Replace with your desired test output path

    split_dataset(source_dir, train_dir, test_dir, train_ratio=0.8, seed=42)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Class 'Asian': 127 images in train, 32 images in test.
# Class 'Indian': 244 images in train, 61 images in test.
# Class 'White': 882 images in train, 221 images in test.
# Class 'Black': 223 images in train, 56 images in test.
# Class 'Others': 20 images in train, 5 images in test.

# %%
# 1) Mount your Google Drive (if your data is on Drive)
from google.colab import drive
drive.mount('/content/drive')

import os
import shutil

def merge_images_into_single_folder(source_dir: str, output_dir: str):
    """
    Collects (copies) all images from multiple subfolders into a single folder.

    Parameters:
    - source_dir: The path to the parent directory containing subfolders
                  (e.g., 'Asian', 'Black', 'Indian', 'Others', 'White').
    - output_dir: The single directory where all images will be copied.
    """

    # Create the output directory if it doesn't exist
    os.makedirs(output_dir, exist_ok=True)

    # Loop over all items in source_dir
    for item in os.listdir(source_dir):
        item_path = os.path.join(source_dir, item)

        # Proceed only if item is a subfolder (e.g. 'Asian', 'Black', etc.)
        if os.path.isdir(item_path):
            # For each subfolder, collect all images
            for file_name in os.listdir(item_path):
                src_file_path = os.path.join(item_path, file_name)

                # Check if this is an image (adjust extensions as needed)
                if os.path.isfile(src_file_path) and file_name.lower().endswith(('.jpg', '.jpeg', '.png')):
                    # Build destination path
                    dst_file_path = os.path.join(output_dir, file_name)

                    # Copy the file (use shutil.move if you want to remove the original)
                    shutil.copy2(src_file_path, dst_file_path)
                    # If file_name might be duplicated across subfolders,
                    # you could rename it or handle collisions here.

    print("Merging complete! Check your output folder.")

# Example usage:
if __name__ == "__main__":
    source_dir = "/content/drive/MyDrive/UTKFace/55_75_train_male"  # your directory with subfolders
    output_dir = "/content/drive/MyDrive/UTKFace/55_75_train_male_merged"  # your merged folder

    merge_images_into_single_folder(source_dir, output_dir)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Merging complete! Check your output folder.
